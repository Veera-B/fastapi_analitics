# %%
print('hello jupitor')
# Out:
# hello jupitor

# %%
2-8
# Out:
# -6

# %%
import requests

endpoint = "get-data"
baseurl = f"http://localhost:8002/{endpoint}"
response = requests.get(baseurl)
print(response.json())
# Out:
# {'message': 'veera you did greate job!'}
