# %%
import requests
requests.get("http://localhost:8002/api/events").json()["message"]
# Out:
# [1, 2, 3]

# %%
import requests
response = requests.get("http://localhost:8002/api/events/34")
print(response.json())
# Out:
# {'id': 34}

# %%
import requests
requests.get("http://localhost:8002/api/events_list").json()
# Out:
# {'result': [{'id': 1}, {'id': 2}, {'id': 3}]}
